# %% [markdown]
# <a href="https://colab.research.google.com/github/jeyam483/Machine-Learning/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Packages

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
import pandas as pd
df = pd.read_csv('/content/iris (version 1).xlsb.csv')
df.head(10)

# %%
df.dropna(inplace =True,axis=1)
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species
# 0           7.9          3.8           6.4          2.0  virginica
# 1           7.7          3.8           6.7          2.2  virginica
# 2           7.7          2.6           6.9          2.3  virginica
# 3           7.7          2.8           6.7          2.0  virginica
# 4           7.7          3.0           6.1          2.3  virginica
# 5           7.6          3.0           6.6          2.1  virginica
# 6           7.4          2.8           6.1          1.9  virginica
# 7           7.3          2.9           6.3          1.8  virginica
# 8           7.2          3.6           6.1          2.5  virginica
# 9           7.2          3.2           6.0          1.8  virginica

# %%
#import numpy as np
#df = np.array(df)

X = df.drop('species',axis=1)
Y = df['species']
print(X,Y)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             7.9          3.8           6.4          2.0
# 1             7.7          3.8           6.7          2.2
# 2             7.7          2.6           6.9          2.3
# 3             7.7          2.8           6.7          2.0
# 4             7.7          3.0           6.1          2.3
# ..            ...          ...           ...          ...
# 142           4.5          2.3           1.3          0.3
# 143           4.4          2.9           1.4          0.2
# 144           4.4          3.0           1.3          0.2
# 145           4.4          3.2           1.3          0.2
# 146           4.3          3.0           1.1          0.1
#
# [147 rows x 4 columns] 0      virginica
# 1      virginica
# 2      virginica
# 3      virginica
# 4      virginica
#          ...
# 142       setosa
# 143       setosa
# 144       setosa
# 145       setosa
# 146       setosa
# Name: species, Length: 147, dtype: object

# %%
X_train,X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.20,random_state=5)

# %% [markdown]
# Fitting The Data Model

# %%
#from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier()
clf.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
score = clf.score(X_test,Y_test)
print(score)
# Out:
# 0.9333333333333333

# %%
predict = clf.predict(X_test)
print(classification_report(Y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       0.91      0.91      0.91        11
#    virginica       0.88      0.88      0.88         8
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
